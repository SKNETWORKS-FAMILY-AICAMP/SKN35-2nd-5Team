# %% [markdown]
# Installed 7 packages in 14.33s
#  성공적으로 데이터를 로드했습니다: (59598, 42)
#  Random Forest 모델 학습 시작...
#
# === Random Forest Model Evaluation ===
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.74      0.75      6252
#            1       0.72      0.75      0.74      5668
#
#     accuracy                           0.74     11920
#    macro avg       0.74      0.75      0.74     11920
# weighted avg       0.75      0.74      0.74     11920
#
# ROC-AUC Score: 0.8356
#
#  모델 파일이 저장되었습니다: C:\sk-encoa\SKN35-2nd-5Team\artifacts\random_forest_model.pkl
#  결과 텍스트 파일이 저장되었습니다: C:\sk-encoa\SKN35-2nd-5Team\artifacts\result_randomforest.txt
